# %% [markdown]
# # Lecture 2: Dictionaries and Tuples
# ---

# %% [markdown]
# This problem set gives students practice defining functions, as well as working with dictionaries and tuples.
#
# **Remark: Make sure you know how to raise an appropriate error in functions.**

# %% [markdown]
# ## Question 1
# Define a function called dict_square, which takes a positive integer $n$ as its only argument, and returns a dictionary that contains a number (between 1 and n) in the form (x, x*x).
#
# **Sample Input**
#
# 5
#
# **Sample Output**
#
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
def dict_square():

# %%
# Question 1 Testing:
print(dict_square(1) == {1:1})
print(dict_square(4) == {1:1,2:4,3:9,4:16})
# Out:
# True
# True

# %% [markdown]
# ## Question 2:
#
# Define a function called switch_key_value, which takes a dictionary as its only argument. Switch the placement of key and value of the dictionary and return it as a new dictionary.
#
# **Sample:**
#
# switch_key_value({'a':1,'b':2})
#
# **Sample Output:**
#
# {1:'a',2:'b'}

# %%
def switch_key_value():

# %%
# Question 2 Testing:
print(switch_key_value({}) == {})
print(switch_key_value({'a':1,'b':2}) == {1:'a',2:'b'})
# Out:
# True
# True

# %% [markdown]
# ## Question 3
# Define a function called sort_list_dict, which takes a dictionary as its only argument, the values of this dictionary are all list. Sort all the lists alphabetically in that dictionary and return it as a new dictionary.
#
# **Sample:**
#
# sort_list_dict({'S': [2, 3, 1], 'T': [5, 1, 2], 'D': [3, 2, 4]})
#
# **Sample Output:**
#
# {'S': [1, 2, 3], 'T': [1, 2, 5], 'D': [2, 3, 4]}

# %%
def sort_list_dict():

# %%
# Question 3 Testing:
print(sort_list_dict({}) == {})
print(sort_list_dict({'a':[]}) == {'a':[]})
print(sort_list_dict({'a':[4,1,2,3],'b':[3,2,1]}) == {'a':[1,2,3,4],'b':[1,2,3]})
# Out:
# True
# True
# True

# %% [markdown]
# ## Question 4:
#
# Define a function called combine, which takes two dictionaries as its argument. Combine the two dictionaries by adding values for common keys and return results as a new dictionary. Your function should raise an appropriate error in the event that the input is not dictionary.
#
# **Sample:**
#
# combine({'a':100,'b':200},{'a':100,'c':200})
#
# **Sample Output:**
#
# {'a':200,'b':200,'c':200}

# %%
def combine():

# %%
# Question 4 Testing:
print(combine({},{}) == {})
print(combine({'a':100},{'b':100}) == {'a':100,'b':100})
print(combine({'a':100,'b':100,'c':300},{'b':100}) == {'a':100,'b':200,'c':300})

# Check for the Exception:
try:
  combine([1],{}) 
  print("X You didn't raise an error for this case")
except TypeError as ex:
  print("You successfully raise a TypeError.")
except Exception as ex:
  print("X You didn't raise an appropriate error for this case (raise " + type(ex).__name__ + " instead of TypeError)")
# Out:
# True
# True
# True
# You successfully raise a TypeError.

# %% [markdown]
# ## Question 5
# Define a function called nest_dict, which takes a list as its only argument, converts the list into a nested dictionary of keys, and returns the dictionary. Your function should raise an appropriate error in the event that the
# input is not a list.
#
# **Sample:**
#
# nest_dict([1,2,3,4])
#
# **Sample Output:**
#
# {1: {2: {3: {4: {}}}}}

# %%
def nest_dict():

# %%
# Question 5 Testing:
print(nest_dict([]) == {})
print(nest_dict([1]) == {1:{}})
print(nest_dict([2,'a',3]) == {2:{'a':{3:{}}}})

# Check for the Exception:
try:
  nest_dict((1,)) 
  print("X You didn't raise an error for this case")
except TypeError as ex:
  print("You successfully raise a TypeError.")
except Exception as ex:
  print("X You didn't raise an appropriate error for this case (raise " + type(ex).__name__ + " instead of TypeError)")
# Out:
# True
# True
# True
# X You didn't raise an appropriate error for this case (raise ValueError instead of TypeError)

# %% [markdown]
# ## Question 6
# Define a function called del_elem_tup, which takes a tuple and an integer $n$ ($0\lt n\le len(tuple)$) as the arguments, deletes the $n$-th element and returns the result. Your function should raise an appropriate error in the event that the type of input is incorrect or n is beyond the range of the tuple's length.
#
# **Sample Input**
#
# del_elem_tup(("S","T","A","T","S"),5)
#
#
# **Sample Output**
#
# ("S","T","T","S")

# %%
def del_elem_tup():

# %%
# Question 6 Testing:
print(del_elem_tup(('a',),1) == tuple())
print(del_elem_tup(("S","T","A","T","S"),5) == ("S","T","A","T"))
print(del_elem_tup(("S","T","A","T","S"),1) == ("T","A","T","S"))

# For TypeError checking, you can refer to question 3 and 4.
# Check for the Exception:
try:
  del_elem_tup(('a', 'b'), 3) 
  print("X You didn't raise an error for this case")
except ValueError as ex:
  print("You successfully raise a ValueError for this case.")
except Exception as ex:
  print("X You didn't raise an appropriate error for this case (raise " + type(ex).__name__ + " instead of ValueError)")
# Out:
# True
# True
# True
# You successfully raise a ValueError for this case.

# %% [markdown]
# ## Question 7
# Define a function called reverse_tuple, which takes a tuple as its only argument, reverse it, and returns the result. Your function should raise an appropriate error in the event that the input is not a tuple.
#
# **Sample Input**
#
# reverse_tuple((5,0,7))
#
# **Sample Output**
#
# (7,0,5)

# %%
def reverse_tuple():

# %%
# Question 7 Testing:
print(reverse_tuple((1,)) == (1,))
print(reverse_tuple((2,1,3)) == (3,1,2))

# Check for the Exception:
try:
  reverse_tuple([]) 
  print("X You didn't raise an error for this case")
except TypeError as ex:
  print("You successfully raise a TypeError.")
except Exception as ex:
  print("X You didn't raise an appropriate error for this case (raise " + type(ex).__name__ + " instead of TypeError)")
# Out:
# True
# True
# You successfully raise a TypeError.

# %% [markdown]
# ## Question 8
# Define a one-line function called rm_empty_tup, which takes a list of tuples as its only argument, remove an empty tuple(s), and returns the result. Your function should raise an appropriate error in the event that the input is not a list or the element of the list is not tuple.
#
# **Sample Input**
#
# rm_empty_tup([(), (), ('',), ('S', 'T'), ('S', 'T', 'D'), ('A')])
#
# **Sample Output**
#
# [('',), ('S', 'T'), ('S', 'T', 'D'), 'A']

# %%
def rm_empty_tup():

# %%
# Question 8 Testing:
print(rm_empty_tup([(),()]) == [])
print(rm_empty_tup([(),(1,),(1,2)]) == [(1,),(1,2)])

# For l's type checking, you can refer to question 3 and 4.
# Check for the Exception:
try:
  rm_empty_tup([[],('a','b')]) 
  print("X You didn't raise an error for this case")
except (ValueError, TypeError) as ex:
  print("You successfully raise a ValueError or TypeError for this case.")
except Exception as ex:
  print("X You didn't raise an appropriate error for this case (raise " + type(ex).__name__ + " instead of ValueError or TypeError)")
# Out:
# True
# True
# You successfully raise a ValueError or TypeError for this case.
